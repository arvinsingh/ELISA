# %%
                                                                                                                                                                                                                                                                                                                                                                                                                            import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %%
import ngram
import pickle
from helpers import *

# %%
data = pd.read_csv("../../Datasets/dataset_1/train.csv", encoding='utf-8')
data.drop(columns=['id', 'author'], inplace=True)

# %%
data.columns = ['Headline',  'articleBody', 'target']
data.head()
# Out:
#                                             Headline  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
#
#                                          articleBody  target
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       1
# 1  Ever get the feeling your life circles the rou...       0
# 2  Why the Truth Might Get You Fired October 29, ...       1
# 3  Videos 15 Civilians Killed In Single US Airstr...       1
# 4  Print \nAn Iranian woman has been sentenced to...       1

# %%
data.info()
data.columns = ['type', 'articleBody', 'Headline']
data = shuffle(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
# id        20800 non-null int64
# title     20242 non-null object
# author    18843 non-null object
# text      20761 non-null object
# label     20800 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
type_rename = {'reliable': 'reliable', 'fake': 'unreliable'}
data['type'] = data['type'].apply(lambda x: type_rename[x])
data.reset_index(drop=True, inplace=True)

# %%
data.target.value_counts()
# Out:
# 1    10413
# 0    10387
# Name: target, dtype: int64

# %%
data.head(10)
# Out:
#                                             Headline  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
# 5  Jackie Mason: Hollywood Would Love Trump if He...
# 6  Life: Life Of Luxury: Elton John’s 6 Favorite ...
# 7  Benoît Hamon Wins French Socialist Party’s Pre...
# 8  Excerpts From a Draft Script for Donald Trump’...
# 9  A Back-Channel Plan for Ukraine and Russia, Co...
#
#                                          articleBody  target
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       1
# 1  Ever get the feeling your life circles the rou...       0
# 2  Why the Truth Might Get You Fired October 29, ...       1
# 3  Videos 15 Civilians Killed In Single US Airstr...       1
# 4  Print \nAn Iranian woman has been sentenced to...       1
# 5  In these trying times, Jackie Mason is the Voi...       0
# 6  Ever wonder how Britain’s most iconic pop pian...       1
# 7  PARIS  —   France chose an idealistic, traditi...       0
# 8  Donald J. Trump is scheduled to make a highly ...       0
# 9  A week before Michael T. Flynn resigned as nat...       0

# %%
# To check for Kaggle dataset
targets = ['0', '1']
targets_dict = dict(zip(targets, ['reliable', 'unreliable']))
targets_dict
# Out:
# {'0': 'reliable', '1': 'unreliable'}

# %%
# For the other dataset
targets = ['0', '1']
targets_dict = dict(zip(targets, ))
targets_dict

# %%
data['type'] = list(map(lambda x: targets_dict[str(x)], data['target']))
data.shape
# Out:
# (20800, 4)

# %%
data.head(10)
# Out:
#                                             Headline  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
# 5  Jackie Mason: Hollywood Would Love Trump if He...
# 6  Life: Life Of Luxury: Elton John’s 6 Favorite ...
# 7  Benoît Hamon Wins French Socialist Party’s Pre...
# 8  Excerpts From a Draft Script for Donald Trump’...
# 9  A Back-Channel Plan for Ukraine and Russia, Co...
#
#                                          articleBody  target        type
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       1  unreliable
# 1  Ever get the feeling your life circles the rou...       0    reliable
# 2  Why the Truth Might Get You Fired October 29, ...       1  unreliable
# 3  Videos 15 Civilians Killed In Single US Airstr...       1  unreliable
# 4  Print \nAn Iranian woman has been sentenced to...       1  unreliable
# 5  In these trying times, Jackie Mason is the Voi...       0    reliable
# 6  Ever wonder how Britain’s most iconic pop pian...       1  unreliable
# 7  PARIS  —   France chose an idealistic, traditi...       0    reliable
# 8  Donald J. Trump is scheduled to make a highly ...       0    reliable
# 9  A week before Michael T. Flynn resigned as nat...       0    reliable

# %%
data.to_csv('../datasets/kaggle_processed.csv', index=False)

# %%
print ("generate unigram")
data["Headline_unigram"] = data["Headline"].map(lambda x: preprocess_data(x))
data["articleBody_unigram"] = data["articleBody"].map(lambda x: preprocess_data(x))
# Out:
# generate unigram

# %%
print ("generate bigram")
join_str = "_"
data["Headline_bigram"] = data["Headline_unigram"].map(lambda x: ngram.getBigram(x, join_str))
data["articleBody_bigram"] = data["articleBody_unigram"].map(lambda x: ngram.getBigram(x, join_str))
# Out:
# generate bigram

# %%
print ("generate trigram")
join_str = "_"
data["Headline_trigram"] = data["Headline_unigram"].map(lambda x: ngram.getTrigram(x, join_str))
data["articleBody_trigram"] = data["articleBody_unigram"].map(lambda x: ngram.getTrigram(x, join_str))
# Out:
# generate trigram

# %%
with open('../saved_data/data_kaggle.pkl', 'wb') as outfile:
    pickle.dump(data, outfile, -1)
    print('dataframe saved in data_kaggle.pkl')
# Out:
# dataframe saved in data.pkl

# %%
data.head(10)
# Out:
#          type                                        articleBody  \
# 0    reliable  The Onion's violent satire painting fictional ...
# 1  unreliable  By Tyler Durden / ZeroHedge Back in May, we fi...
# 2  unreliable  In New York City, yesterday’s morning commute ...
# 3  unreliable  zerohedge.com / by Steve Saretsky via VanCityC...
# 4  unreliable  In August number, Europe’s major powers threw ...
# 5  unreliable  Since CME unleashed its Bitcoin Futures, crypt...
# 6  unreliable  Crazy Stupid Earth, Crazy Stupid Time we are l...
# 7  unreliable  “People should not be afraid of their governme...
# 8    reliable   A Federal Emergency Management Agency employe...
# 9  unreliable  November number, number A city full of people ...
#
#                                             Headline  target  \
# 0  The Onion's Spoof Tweets Spark Anger, Fear; No...       0
# 1  “Here’s Why Current Situation is Even Worse Th...       1
# 2                       What Is the World Coming to?       1
# 3  Canadian Homeowners Take Out HELOCs To Fund Su...       1
# 4                 The Christmas Truce of World War I       1
# 5  Cryptos Slide: “Is There Any New Information T...       1
# 6       Transition Period Strategy and Policy Advice       1
# 7                              The Myth of Authority       1
# 8  Judge Gives FEMA number Weeks to Change Policy...       0
# 9                                       The Waitress       1
#
#                                     Headline_unigram  \
# 0  [onion, spoof, tweet, spark, anger, fear, laug...
# 1  [whi, current, situat, even, wors, number, cri...
# 2                                      [world, come]
# 3  [canadian, homeown, take, heloc, fund, subprim...
# 4                      [christma, truce, world, war]
# 5  [crypto, slide, ani, new, inform, exist, two, ...
# 6         [transit, period, strategi, polici, advic]
# 7                                     [myth, author]
# 8  [judg, give, fema, number, week, chang, polici...
# 9                                         [waitress]
#
#                                  articleBody_unigram  \
# 0  [onion, violent, satir, paint, fiction, imag, ...
# 1  [tyler, durden, zerohedg, back, may, first, re...
# 2  [new, york, citi, yesterday, morn, commut, int...
# 3  [zerohedg, com, steve, saretski, via, vancityc...
# 4  [august, number, europ, major, power, threw, t...
# 5  [sinc, cme, unleash, bitcoin, futur, cryptocur...
# 6  [crazi, stupid, earth, crazi, stupid, time, li...
# 7  [peopl, afraid, govern, govern, afraid, peopl,...
# 8  [feder, emerg, manag, agenc, employe, wait, ar...
# 9  [novemb, number, number, citi, full, peopl, fa...
#
#                                      Headline_bigram  \
# 0  [onion_spoof, spoof_tweet, tweet_spark, spark_...
# 1  [whi_current, current_situat, situat_even, eve...
# 2                                       [world_come]
# 3  [canadian_homeown, homeown_take, take_heloc, h...
# 4           [christma_truce, truce_world, world_war]
# 5  [crypto_slide, slide_ani, ani_new, new_inform,...
# 6  [transit_period, period_strategi, strategi_pol...
# 7                                      [myth_author]
# 8  [judg_give, give_fema, fema_number, number_wee...
# 9                                         [waitress]
#
#                                   articleBody_bigram  \
# 0  [onion_violent, violent_satir, satir_paint, pa...
# 1  [tyler_durden, durden_zerohedg, zerohedg_back,...
# 2  [new_york, york_citi, citi_yesterday, yesterda...
# 3  [zerohedg_com, com_steve, steve_saretski, sare...
# 4  [august_number, number_europ, europ_major, maj...
# 5  [sinc_cme, cme_unleash, unleash_bitcoin, bitco...
# 6  [crazi_stupid, stupid_earth, earth_crazi, craz...
# 7  [peopl_afraid, afraid_govern, govern_govern, g...
# 8  [feder_emerg, emerg_manag, manag_agenc, agenc_...
# 9  [novemb_number, number_number, number_citi, ci...
#
#                                     Headline_trigram  \
# 0  [onion_spoof_tweet, spoof_tweet_spark, tweet_s...
# 1  [whi_current_situat, current_situat_even, situ...
# 2                                       [world_come]
# 3  [canadian_homeown_take, homeown_take_heloc, ta...
# 4            [christma_truce_world, truce_world_war]
# 5  [crypto_slide_ani, slide_ani_new, ani_new_info...
# 6  [transit_period_strategi, period_strategi_poli...
# 7                                      [myth_author]
# 8  [judg_give_fema, give_fema_number, fema_number...
# 9                                         [waitress]
#
#                                  articleBody_trigram
# 0  [onion_violent_satir, violent_satir_paint, sat...
# 1  [tyler_durden_zerohedg, durden_zerohedg_back, ...
# 2  [new_york_citi, york_citi_yesterday, citi_yest...
# 3  [zerohedg_com_steve, com_steve_saretski, steve...
# 4  [august_number_europ, number_europ_major, euro...
# 5  [sinc_cme_unleash, cme_unleash_bitcoin, unleas...
# 6  [crazi_stupid_earth, stupid_earth_crazi, earth...
# 7  [peopl_afraid_govern, afraid_govern_govern, go...
# 8  [feder_emerg_manag, emerg_manag_agenc, manag_a...
# 9  [novemb_number_number, number_number_citi, num...

# %% [markdown]
# ## The preprocessing and data pickle Ends Here!
# ### Next step>>> Get features.

# %% [markdown]
# ## Generating Targets features for reading labels

# %%
with open('../saved_data/data_kaggle.pkl', 'rb') as infile:
    data = pickle.load(infile)

# %%
data.head(10)
# Out:
#          type                                        articleBody  \
# 0    reliable  The Onion's violent satire painting fictional ...
# 1  unreliable  By Tyler Durden / ZeroHedge Back in May, we fi...
# 2  unreliable  In New York City, yesterday’s morning commute ...
# 3  unreliable  zerohedge.com / by Steve Saretsky via VanCityC...
# 4  unreliable  In August number, Europe’s major powers threw ...
# 5  unreliable  Since CME unleashed its Bitcoin Futures, crypt...
# 6  unreliable  Crazy Stupid Earth, Crazy Stupid Time we are l...
# 7  unreliable  “People should not be afraid of their governme...
# 8    reliable   A Federal Emergency Management Agency employe...
# 9  unreliable  November number, number A city full of people ...
#
#                                             Headline  target  \
# 0  The Onion's Spoof Tweets Spark Anger, Fear; No...       0
# 1  “Here’s Why Current Situation is Even Worse Th...       1
# 2                       What Is the World Coming to?       1
# 3  Canadian Homeowners Take Out HELOCs To Fund Su...       1
# 4                 The Christmas Truce of World War I       1
# 5  Cryptos Slide: “Is There Any New Information T...       1
# 6       Transition Period Strategy and Policy Advice       1
# 7                              The Myth of Authority       1
# 8  Judge Gives FEMA number Weeks to Change Policy...       0
# 9                                       The Waitress       1
#
#                                     Headline_unigram  \
# 0  [onion, spoof, tweet, spark, anger, fear, laug...
# 1  [whi, current, situat, even, wors, number, cri...
# 2                                      [world, come]
# 3  [canadian, homeown, take, heloc, fund, subprim...
# 4                      [christma, truce, world, war]
# 5  [crypto, slide, ani, new, inform, exist, two, ...
# 6         [transit, period, strategi, polici, advic]
# 7                                     [myth, author]
# 8  [judg, give, fema, number, week, chang, polici...
# 9                                         [waitress]
#
#                                  articleBody_unigram  \
# 0  [onion, violent, satir, paint, fiction, imag, ...
# 1  [tyler, durden, zerohedg, back, may, first, re...
# 2  [new, york, citi, yesterday, morn, commut, int...
# 3  [zerohedg, com, steve, saretski, via, vancityc...
# 4  [august, number, europ, major, power, threw, t...
# 5  [sinc, cme, unleash, bitcoin, futur, cryptocur...
# 6  [crazi, stupid, earth, crazi, stupid, time, li...
# 7  [peopl, afraid, govern, govern, afraid, peopl,...
# 8  [feder, emerg, manag, agenc, employe, wait, ar...
# 9  [novemb, number, number, citi, full, peopl, fa...
#
#                                      Headline_bigram  \
# 0  [onion_spoof, spoof_tweet, tweet_spark, spark_...
# 1  [whi_current, current_situat, situat_even, eve...
# 2                                       [world_come]
# 3  [canadian_homeown, homeown_take, take_heloc, h...
# 4           [christma_truce, truce_world, world_war]
# 5  [crypto_slide, slide_ani, ani_new, new_inform,...
# 6  [transit_period, period_strategi, strategi_pol...
# 7                                      [myth_author]
# 8  [judg_give, give_fema, fema_number, number_wee...
# 9                                         [waitress]
#
#                                   articleBody_bigram  \
# 0  [onion_violent, violent_satir, satir_paint, pa...
# 1  [tyler_durden, durden_zerohedg, zerohedg_back,...
# 2  [new_york, york_citi, citi_yesterday, yesterda...
# 3  [zerohedg_com, com_steve, steve_saretski, sare...
# 4  [august_number, number_europ, europ_major, maj...
# 5  [sinc_cme, cme_unleash, unleash_bitcoin, bitco...
# 6  [crazi_stupid, stupid_earth, earth_crazi, craz...
# 7  [peopl_afraid, afraid_govern, govern_govern, g...
# 8  [feder_emerg, emerg_manag, manag_agenc, agenc_...
# 9  [novemb_number, number_number, number_citi, ci...
#
#                                     Headline_trigram  \
# 0  [onion_spoof_tweet, spoof_tweet_spark, tweet_s...
# 1  [whi_current_situat, current_situat_even, situ...
# 2                                       [world_come]
# 3  [canadian_homeown_take, homeown_take_heloc, ta...
# 4            [christma_truce_world, truce_world_war]
# 5  [crypto_slide_ani, slide_ani_new, ani_new_info...
# 6  [transit_period_strategi, period_strategi_poli...
# 7                                      [myth_author]
# 8  [judg_give_fema, give_fema_number, fema_number...
# 9                                         [waitress]
#
#                                  articleBody_trigram
# 0  [onion_violent_satir, violent_satir_paint, sat...
# 1  [tyler_durden_zerohedg, durden_zerohedg_back, ...
# 2  [new_york_citi, york_citi_yesterday, citi_yest...
# 3  [zerohedg_com_steve, com_steve_saretski, steve...
# 4  [august_number_europ, number_europ_major, euro...
# 5  [sinc_cme_unleash, cme_unleash_bitcoin, unleas...
# 6  [crazi_stupid_earth, stupid_earth_crazi, earth...
# 7  [peopl_afraid_govern, afraid_govern_govern, go...
# 8  [feder_emerg_manag, emerg_manag_agenc, manag_a...
# 9  [novemb_number_number, number_number_citi, num...

# %%
processed = data[['type', 'articleBody', 'Headline']]

# %%
processed.to_csv('../datasets/processed_kaggle.csv', index_label='id')

# %%
targets = data[['Headline', 'target']]

# %%
targets.head(10)
# Out:
#                                             Headline  target
# 0  The Onion's Spoof Tweets Spark Anger, Fear; No...       0
# 1  “Here’s Why Current Situation is Even Worse Th...       1
# 2                       What Is the World Coming to?       1
# 3  Canadian Homeowners Take Out HELOCs To Fund Su...       1
# 4                 The Christmas Truce of World War I       1
# 5  Cryptos Slide: “Is There Any New Information T...       1
# 6       Transition Period Strategy and Policy Advice       1
# 7                              The Myth of Authority       1
# 8  Judge Gives FEMA number Weeks to Change Policy...       0
# 9                                       The Waitress       1

# %%
targets.to_csv('../datasets/targets_kaggle.csv', index_label='id')
