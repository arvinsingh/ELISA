# %% [markdown]
# # Classifying articles according to their types

# %%
import pandas as pd

# %% [markdown]
# ### Data not split yet

# %%
newsreader = pd.read_csv(open('../Datasets/news_cleaned_2018_02_13.csv', 'rU'), iterator=True)
# Out:
# /opt/Anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
news = newsreader.get_chunk(1000)

# %%
news.columns
# Out:
# Index(['Unnamed: 0', 'id', 'domain', 'type', 'url', 'content', 'scraped_at',
#        'inserted_at', 'updated_at', 'title', 'authors', 'keywords',
#        'meta_keywords', 'meta_description', 'tags', 'summary', 'source'],
#       dtype='object')

# %%
news.drop(columns=['Unnamed: 0', 'id', 'domain', 'url', 'scraped_at',
       'inserted_at', 'updated_at', 'keywords',
       'meta_keywords', 'meta_description', 'tags', 'summary', 'source'], inplace=True)

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
# type       997 non-null object
# content    1000 non-null object
# title      1000 non-null object
# authors    638 non-null object
# dtypes: object(4)
# memory usage: 31.3+ KB

# %%
news.head()
# Out:
#     type                                            content  \
# 0  rumor  Life is an illusion, at least on a quantum lev...
# 1   hate  Unfortunately, he hasn’t yet attacked her for ...
# 2   hate  The Los Angeles Police Department has been den...
# 3   hate  The White House has decided to quietly withdra...
# 4   hate  “The time has come to cut off the tongues of t...
#
#                                                title  \
# 0  Is life an ILLUSION? Researchers prove 'realit...
# 1                                       Donald Trump
# 2                                       Donald Trump
# 3  MORE WINNING! Israeli intelligence source, DEB...
# 4  “Oh, Trump, you coward, you just wait, we will...
#
#                                              authors
# 0                                        Sean Martin
# 1  Linda Rivera, Conrad Calvano, Az Gal, Lincoln ...
# 2  Linda Rivera, Conrad Calvano, Az Gal, Lincoln ...
# 3  Cleavis Nowell, Cleavisnowell, Clarence J. Fei...
# ...

# %%
news.type.value_counts()
# Out:
# unreliable    217
# conspiracy    149
# clickbait     136
# fake          124
# satire        112
# hate           99
# political      62
# reliable       58
# bias           21
# junksci        17
# rumor           1
# unknown         1
# Name: type, dtype: int64

# %%
news.iloc[5]['content']
# Out:
# 'The Central American nation and six other states voted with the US and Israel, in contrast to the rest of the UN General Assembly which last week voted 128-9 to condemn the US decision to recognize Jerusalem.\n\nHotovely did not name any of the 10 countries, but said many had a strong Christian tradition. Philippines, the Czech Republic and Romania abstained from the UNGA vote last week, but have entertained the possibility of joining Guatemala and the United States, with Czech President Milos Zeman supporting the move to Jerusalem.\n\n“I spoke yesterday with my friend the Guatemalan president, and thanked him for his support of us through his vote in the UN,” he said in the Knesset. “I expressed my hope that he will follow President Trump’s footsteps and recognize Jerusalem as Israel’s capital, and will begin the process of moving the embassy there. That night he released an announcement that he would in fact do so. So I want to say, from here, to the president of Guatemala: May Go
# ...

# %%
del newsreader
del news

# %% [markdown]
# ## Main Code

# %%
news_types = ['fake', 'political', 'conspiracy',
              'junksci', 'bias', 'unreliable',
              'unknown', 'satire', 'reliable',
              'hate', 'clickbait', 'rumor'
             ]

# %%
path = '../Datasets/newsSplit/'

# %%
# Because for loop looked too messy with these.
def news_filter(newsdf):
    
    global once
    
    def header_once(header=False):
        """Helps to add the header once for every iteration.
        """
        # header gets added after each iteration.
        political.to_csv(path + 'political.csv',mode = 'a', header=header, index=False)
        conspiracy.to_csv(path + 'conspiracy.csv',mode = 'a', header=header, index=False)
        junksci.to_csv(path + 'junksci.csv',mode = 'a', header=header, index=False)
        bias.to_csv(path + 'bias.csv',mode = 'a', header=header, index=False)
        unreliable.to_csv(path + 'unreliable.csv',mode = 'a', header=header, index=False)
        unknown.to_csv(path + 'unknown.csv',mode = 'a', header=header, index=False)
        satire.to_csv(path + 'satire.csv',mode = 'a', header=header, index=False)
        reliable.to_csv(path + 'reliable.csv',mode = 'a', header=header, index=False)
        hate.to_csv(path + 'hate.csv',mode = 'a', header=header, index=False)
        clickbait.to_csv(path + 'clickbait.csv',mode = 'a', header=header, index=False)
        rumor.to_csv(path + 'rumor.csv',mode = 'a', header=header, index=False)
        fake.to_csv(path + 'fake.csv',mode = 'a', header=header, index=False)  
    
    fake = newsdf[newsdf['type'].astype(str) == 'fake']
    political  = newsdf[newsdf['type'].astype(str) == 'political']
    conspiracy = newsdf[newsdf['type'].astype(str) == 'conspiracy']
    junksci = newsdf[newsdf['type'].astype(str) == 'junksci']
    bias = newsdf[newsdf['type'].astype(str) == 'bias']
    unreliable = newsdf[newsdf['type'].astype(str) == 'unreliable']
    unknown = newsdf[newsdf['type'].astype(str) == 'unknown']
    satire = newsdf[newsdf['type'].astype(str) == 'satire']
    reliable = newsdf[newsdf['type'].astype(str) == 'reliable']
    hate = newsdf[newsdf['type'].astype(str) == 'hate']
    clickbait = newsdf[newsdf['type'].astype(str) == 'clickbait']
    rumor = newsdf[newsdf['type'].astype(str) == 'rumor']
    
    if once:
        header_once(once)
        once=False
    else:
        header_once()

# %%
newsreader = pd.read_csv(open('../Datasets/news_cleaned_2018_02_13.csv', 'rU'), chunksize=100000)
# Out:
# /opt/Anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
once = True

for newsdf in newsreader:
    newsdf.drop(columns=['Unnamed: 0', 'id', 'domain', 'url', 'scraped_at',
                       'inserted_at', 'updated_at', 'keywords','meta_keywords',
                       'meta_description', 'tags', 'summary', 'source'],
              inplace=True)
    news_filter(newsdf)
# Out:
# /opt/Anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/Anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/Anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/Anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# #### Check results

# %%
test = pd.read_csv(path + 'satire.csv', iterator=True)

# %%
test.get_chunk(100).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# type       100 non-null object
# content    100 non-null object
# title      100 non-null object
# authors    18 non-null object
# dtypes: object(4)
# memory usage: 3.2+ KB

# %%
test.get_chunk(100).head()
# Out:
#        type                                            content  \
# 100  satire  People who are awake right now, you’re gonna w...
# 101  satire  Hidden among the dense rainforests of the Amaz...
# 102  satire  If you’ve been playing EA’s Madden NFL 18 and ...
# 103  satire  THE “illness” that has forced Raheem Sterling ...
# 104  satire  A man’s ego was shattered Thursday while in th...
#
#                                                  title authors
# 100  Log Off Now: Researchers Have Determined That ...     NaN
# 101  Incredible: This Remote Amazon Tribe Is Only O...     NaN
# 102  Much-Needed Fix: EA Has Announced An Upcoming ...     NaN
# 103  Raheem Sterling’s Mother hands in ‘sick note’ ...     NaN
# 104  Health – Chronicle.su – The only news that mat...     NaN

# %% [markdown]
# ### Splitting the data yet again,
# #### for more balanced and manageable chunks.
# ##### Only first 10000 articles are needed here.

# %%
chunk_size = 10000

# %%
path_mini = '../Datasets/MiniSplits/'

# %%
for file in news_types:
    split_reader = pd.read_csv(path + file + '.csv', iterator=True)
    split_reader.get_chunk(chunk_size).to_csv(path_mini + file + '_mini.csv', mode='a', index=False)
    del split_reader

# %% [markdown]
# #### Check results

# %%
for file in news_types:
    test_mini = pd.read_csv(path_mini + file + '_small.csv')
    print(len(test_mini.index))
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000

# %%
test_mini
# Out:
#        type                                            content  \
# 0     rumor  Life is an illusion, at least on a quantum lev...
# 1     rumor  Dr Paul Miller, who served on the US’s Nationa...
# 2     rumor  Fahad bin Mohammed Al-Attiyah is quoted as say...
# 3     rumor  In the weeks before terrorists ploughed a van ...
# 4     rumor  The train, which was full of commuters, derail...
# 5     rumor  The pervert pleaded guilty to 10 counts of sex...
# 6     rumor  The children were tied up with ropes after one...
# 7     rumor  The train was heading towards Milan before it ...
# 8     rumor  The Mayon volcano, which stands at 8,077 foot ...
# 9     rumor  European chiefs are seriously worried about th...
# 10    rumor  Jacques Myard, a former Member of French Parli...
# 11    rumor  The pub boss accused the Confederation of Brit...
# 12    rumor  The spike in membership applications follows a...
# 13    rumor  North Korea has issued a rare statement to cit...
# ...

# %% [markdown]
# # Only Splitting is done here. Further cleaning needs to be performed.
