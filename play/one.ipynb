# %% [markdown]
# # Articles sepration based on their specified type #

# %%
import pandas as pd
import csv

# %%
# uncomment for use 
# Reading N numbers of row of a file.
'''outfile = open('/home/sourabh/Desktop/test/thousand.csv','a')
with open('/media/sourabh/Essentials/CSV/news_cleaned_2018_02_13.csv') as corpus:
    reader = csv.DictReader(corpus)
    columns_names = ['Unnamed: 0', 'id', 'domain', 'type', 'url', 'content', 'scraped_at',
       'inserted_at', 'updated_at', 'title', 'authors', 'keywords',
       'meta_keywords', 'meta_description', 'tags', 'summary', 'source','']
    writer = csv.DictWriter(outfile, fieldnames=columns_names)
    writer.writeheader()
    rows_count = 0
    for row in reader:
        rows_count += 1
        if rows_count > 50000:
            break
        writer.writerow(row)
outfile.close()'''

# %%
# DataFrame _init_
news = pd.read_csv('/home/sourabh/Desktop/test/thousand.csv')
news.drop(columns=['Unnamed: 0','Unnamed: 17'],inplace=True)
news.type.value_counts()
# Out:
# fake          25420
# political     10489
# conspiracy     5297
# junksci        1361
# bias           1224
# unreliable      930
# unknown         740
# satire          339
# reliable        273
# hate            272
# clickbait       267
# rumor            96
# Name: type, dtype: int64

# %%
news.columns
# Out:
# Index(['id', 'domain', 'type', 'url', 'content', 'scraped_at', 'inserted_at',
#        'updated_at', 'title', 'authors', 'keywords', 'meta_keywords',
#        'meta_description', 'tags', 'summary', 'source'],
#       dtype='object')

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
# id                  50000 non-null int64
# domain              50000 non-null object
# type                46708 non-null object
# url                 50000 non-null object
# content             50000 non-null object
# scraped_at          50000 non-null object
# inserted_at         50000 non-null object
# updated_at          50000 non-null object
# title               49974 non-null object
# authors             35574 non-null object
# keywords            0 non-null float64
# meta_keywords       50000 non-null object
# meta_description    16101 non-null object
# tags                11069 non-null object
# summary             0 non-null float64
# source              0 non-null float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 6.1+ MB

# %%
news.head()
# Out:
#    id              domain   type  \
# 0   2       express.co.uk  rumor
# 1   6  barenakedislam.com   hate
# 2   7  barenakedislam.com   hate
# 3   8  barenakedislam.com   hate
# 4   9  barenakedislam.com   hate
#
#                                                  url  \
# 0  https://www.express.co.uk/news/science/738402/...
# 1  http://barenakedislam.com/category/donald-trum...
# 2  http://barenakedislam.com/category/donald-trum...
# 3  http://barenakedislam.com/2017/12/24/more-winn...
# 4  http://barenakedislam.com/2017/12/25/oh-trump-...
#
#                                              content  \
# 0  Life is an illusion, at least on a quantum lev...
# 1  Unfortunately, he hasn’t yet attacked her for ...
# 2  The Los Angeles Police Department has been den...
# 3  The White House has decided to quietly withdra...
# 4  “The time has come to cut off the tongues of t...
#
#                    scraped_at                 inserted_at  \
# ...

# %%
news.iloc[5]['content']
# Out:
# 'The Central American nation and six other states voted with the US and Israel, in contrast to the rest of the UN General Assembly which last week voted 128-9 to condemn the US decision to recognize Jerusalem.\n\nHotovely did not name any of the 10 countries, but said many had a strong Christian tradition. Philippines, the Czech Republic and Romania abstained from the UNGA vote last week, but have entertained the possibility of joining Guatemala and the United States, with Czech President Milos Zeman supporting the move to Jerusalem.\n\n“I spoke yesterday with my friend the Guatemalan president, and thanked him for his support of us through his vote in the UN,” he said in the Knesset. “I expressed my hope that he will follow President Trump’s footsteps and recognize Jerusalem as Israel’s capital, and will begin the process of moving the embassy there. That night he released an announcement that he would in fact do so. So I want to say, from here, to the president of Guatemala: May Go
# ...

# %%
# DataFrames made based on their types

fake = news[news['type'] == 'fake']
political  = news[news['type'] == 'political']
conspiracy = news[news['type'] == 'conspiracy']
junksci = news[news['type'] == 'junksci']
bias = news[news['type'] == 'bias']
unreliable = news[news['type'] == 'unreliable']
unknown = news[news['type'] == 'unknown']
satire = news[news['type'] == 'satire']
reliable = news[news['type'] == 'reliable']
hate = news[news['type'] == 'hate']
clickbait = news[news['type'] == 'clickbait']
rumor = news[news['type'] == 'rumor']

# %%
political.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10489 entries, 136 to 49998
# Data columns (total 16 columns):
# id                  10489 non-null int64
# domain              10489 non-null object
# type                10489 non-null object
# url                 10489 non-null object
# content             10489 non-null object
# scraped_at          10489 non-null object
# inserted_at         10489 non-null object
# updated_at          10489 non-null object
# title               10488 non-null object
# authors             9197 non-null object
# keywords            0 non-null float64
# meta_keywords       10489 non-null object
# meta_description    8978 non-null object
# tags                4038 non-null object
# summary             0 non-null float64
# source              0 non-null float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 1.4+ MB

# %%
# Writing into Files:
political.to_csv('/home/sourabh/Desktop/test/political.csv')

# %%
conspiracy.to_csv('/home/sourabh/Desktop/test/conspiracy.csv')
junksci.to_csv('/home/sourabh/Desktop/test/junksci.csv')
bias.to_csv('/home/sourabh/Desktop/test/bias.csv')
unreliable.to_csv('/home/sourabh/Desktop/test/unreliable.csv')
unknown.to_csv('/home/sourabh/Desktop/test/unknown.csv')
satire.to_csv('/home/sourabh/Desktop/test/satire.csv')
reliable.to_csv('/home/sourabh/Desktop/test/reliable.csv')
hate.to_csv('/home/sourabh/Desktop/test/hate.csv')
clickbait.to_csv('/home/sourabh/Desktop/test/clickbait.csv')
rumor.to_csv('/home/sourabh/Desktop/test/rumor.csv')
fake.to_csv('/home/sourabh/Desktop/test/fake.csv')

# %%
# Sanity check
political = pd.read_csv('/home/sourabh/Desktop/test/political.csv')
political.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10489 entries, 0 to 10488
# Data columns (total 17 columns):
# Unnamed: 0          10489 non-null int64
# id                  10489 non-null int64
# domain              10489 non-null object
# type                10489 non-null object
# url                 10489 non-null object
# content             10489 non-null object
# scraped_at          10489 non-null object
# inserted_at         10489 non-null object
# updated_at          10489 non-null object
# title               10488 non-null object
# authors             9197 non-null object
# keywords            0 non-null float64
# meta_keywords       10489 non-null object
# meta_description    8978 non-null object
# tags                4038 non-null object
# summary             0 non-null float64
# source              0 non-null float64
# dtypes: float64(3), int64(2), object(12)
# memory usage: 1.4+ MB

# %%
# Index has to re-initialized or not !
political.head()
# Out:
#       id           domain       type  \
# 136  160  baptistnews.com  political
# 137  161  baptistnews.com  political
# 158  185  baptistnews.com  political
# 159  187  baptistnews.com  political
# 160  188  baptistnews.com  political
#
#                                                    url  \
# 136  https://baptistnews.com/article/finding-wonder...
# 137    https://baptistnews.com/article/god-works-work/
# 158  https://baptistnews.com/article/god-play-favor...
# 159  https://baptistnews.com/article/putting-god-test/
# 160  https://baptistnews.com/article/metoo-culture-...
#
#                                                content  \
# 136  It is rather hard to write with eclipse glasse...
# 137  As our nation celebrated Labor Day, giving att...
# 158  We hear quite a bit about survivors’ guilt the...
# 159  The study of the Hebrew language did not come ...
# 160  Social media is blowing up about a culture of ...
#
#                      scraped_at                 inserted_at  \
# ...

# %% [markdown]
# # This method also works

# %%
t = pd.read_csv('/home/sourabh/Desktop/test/thousand.csv', chunksize = 10)

# %%
for i in t:
    p = i[i['type'].astype(str) == 'political']
    p.to_csv('/home/sourabh/Desktop/test/test.csv',mode = 'a')

# %%
x = pd.read_csv('/home/sourabh/Desktop/test/test.csv')

# %%
x.drop(columns=['Unnamed: 0','Unnamed: 17','Unnamed: 0.1'],inplace=True)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15488 entries, 0 to 15487
# Data columns (total 16 columns):
# id                  15488 non-null object
# domain              15488 non-null object
# type                15488 non-null object
# url                 15488 non-null object
# content             15488 non-null object
# scraped_at          15488 non-null object
# inserted_at         15488 non-null object
# updated_at          15488 non-null object
# title               15487 non-null object
# authors             14196 non-null object
# keywords            4999 non-null object
# meta_keywords       15488 non-null object
# meta_description    13977 non-null object
# tags                9037 non-null object
# summary             4999 non-null object
# source              4999 non-null object
# dtypes: object(16)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Not as per our Expectation ...

# %%
x
# Out:
#           id              domain       type  \
# 0         id              domain       type
# 1         id              domain       type
# 2         id              domain       type
# 3         id              domain       type
# 4         id              domain       type
# 5         id              domain       type
# 6         id              domain       type
# 7         id              domain       type
# 8         id              domain       type
# 9         id              domain       type
# 10        id              domain       type
# 11        id              domain       type
# 12        id              domain       type
# 13       160     baptistnews.com  political
# 14       161     baptistnews.com  political
# 15        id              domain       type
# 16        id              domain       type
# 17       185     baptistnews.com  political
# 18       187     baptistnews.com  political
# 19        id              domain       type
# ...

# %%
# But this can be used to get the job Done fast!
